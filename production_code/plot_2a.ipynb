# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
##CLASS1


eta40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_40_V_0.03_L_6.2_R_1_avg_20_nb_pts_50_Class1.npy')
v40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_40_V_0.03_L_6.2_R_1_avg_20_nb_pts_50_Class1.npy')
v_uncertainty40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_40_V_0.03_L_6.2_R_1_avg_20_nb_pts_50_Class1.npy')

eta100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_100_V_0.03_L_9.8_R_1_avg_20_nb_pts_50_Class1.npy')
v100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_100_V_0.03_L_9.8_R_1_avg_20_nb_pts_50_Class1.npy')
v_uncertainty100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_100_V_0.03_L_9.8_R_1_avg_20_nb_pts_50_Class1.npy')

eta400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_400_V_0.03_L_19.6_R_1_avg_20_nb_pts_50_Class1.npy')
v400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_400_V_0.03_L_19.6_R_1_avg_20_nb_pts_50_Class1.npy')
v_uncertainty400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_400_V_0.03_L_19.6_R_1_avg_20_nb_pts_50_Class1.npy')

plt.figure(figsize=(6, 6))
plt.errorbar(eta40, v40, yerr=v_uncertainty40, color='r', ecolor='y', fmt='*', capthick=2, label='N=40')
plt.errorbar(eta100, v100, yerr=v_uncertainty100, color='b', ecolor='y', fmt='x',capthick=2, label='N=100')
plt.errorbar(eta400, v400, yerr=v_uncertainty400, color='g', ecolor='y',fmt='+', capthick=2, label='N=400')

plt.axis([0,5.0,0,1.03])
plt.legend()
plt.grid()
plt.xlabel("$\eta$", fontsize=20)
ylabel=plt.ylabel("$v_{a}$", fontsize=20)
ylabel.set_rotation(0)
plt.gca().yaxis.set_label_coords(-0.15, 0.45)
title=plt.title("Evolution of the order parameter with respect to $\eta$, Simple Model", fontsize = 12)
title.set_position([0.5, 1.2])

# %%
##CLASS2


eta40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_40_V_0.03_L_6.2_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_40_V_0.03_L_6.2_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v_uncertainty40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_40_V_0.03_L_6.2_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')

eta100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_100_V_0.03_L_9.8_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_100_V_0.03_L_9.8_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v_uncertainty100 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_100_V_0.03_L_9.8_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')

eta400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_400_V_0.03_L_19.6_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_avg_it_200_N_400_V_0.03_L_19.6_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')
v_uncertainty400 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_uncertainty_it_200_N_400_V_0.03_L_19.6_R1_1_R2_2_R3_3_avg_20_nb_pts_50_Class2.npy')

plt.figure(figsize=(6, 6))
plt.errorbar(eta40, v40, yerr=v_uncertainty40, color='r', ecolor='y', fmt='*', capthick=2, label='N=40')
plt.errorbar(eta100, v100, yerr=v_uncertainty100, color='b', ecolor='y', fmt='x',capthick=2, label='N=100')
plt.errorbar(eta400, v400, yerr=v_uncertainty400, color='g', ecolor='y',fmt='+', capthick=2, label='N=400')

plt.axis([0,5.0,0,1.03])
plt.legend()
plt.grid()
plt.xlabel("$\eta$", fontsize=20)
ylabel=plt.ylabel("$v_{a}$", fontsize=20)
ylabel.set_rotation(0)
plt.gca().yaxis.set_label_coords(-0.15, 0.45)
title=plt.title("Evolution of the order parameter with respect to $\eta$, Complex Model", fontsize = 12)
title.set_position([0.5, 1.2])

# %%
##CLASS1, first densities with no inflexion


eta40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/eta_it_200_N_40_V_0.03_L_3.1_R_1_avg_50_nb_pts_50.npy')
v40 = np.load('C:/Users/cleme/Documents/_PYTHON/PHY571/results/v_it_200_N_40_V_0.03_L_3.1_R_1_avg_50_nb_pts_50.npy')

plt.figure(figsize=(6, 6))
plt.scatter(eta40, v40, color='b', label='N=40')
#plt.errorbar(eta100, v100, yerr=v_uncertainty100, color='b', ecolor='y', fmt='x',capthick=2, label='N=100')
#plt.errorbar(eta400, v400, yerr=v_uncertainty400, color='g', ecolor='y',fmt='+', capthick=2, label='N=400')

plt.axis([0,5.0,0,1.03])
plt.legend()
plt.grid()
plt.xlabel("$\eta$", fontsize=20)
ylabel=plt.ylabel("$v_{a}$", fontsize=20)
ylabel.set_rotation(0)
plt.gca().yaxis.set_label_coords(-0.15, 0.45)
title=plt.title("Evolution of the order parameter with respect to $\eta$, Simple Model", fontsize = 12)
title.set_position([0.5, 1.2])
